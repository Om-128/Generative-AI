# %% [markdown]
# # Langchain with OpenAI
#  - Getting started with LangChain, LangSmith, LangServe.
#  - Common components of LangChain -> prompt templates, models, output parsers.
#  - Build application with LangChain.
#  - Trace your application with LangSmith.
#  - Serve your application with LangServe.

# %%
import os
from google import genai
from dotenv import load_dotenv

# %%
load_dotenv()
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
print(os.getenv("GEMINI_API_KEY"))
# Out:
# AIzaSyAF5zza0mGN0NWhTSz4-IU6rzq17bLtgyU

# %%
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="who is silver Rayleigh tell me in 5 words"
)

print(response.text)
# Out:
# Roger's legendary First Mate, powerful.
